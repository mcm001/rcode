# %%
# Out:
# /Io': ''}, 'Power Control': {'Rx Power': ''}}, 'CDMA': {'System': {'BID': '', 'Band Class': '', 'ESN': '', 'NID': '', 'RF Mode': '', 'SID': ''}}, 'CI_1': '', 'CI_2': '', 'Call Test': {'VoLTE': {'Duration': {'SIP Setup Duration (~Conversation)': ''}, 'RTP Analysis': {'Rx Loss (Count)': '', 'Rx OutOfSeq Count': ''}}, 'Voice or Video Call': {'Call Result': '', 'Duration': {'Setup Duration (LoggingTool)': ''}, 'Real Service': ''}}, 'Event': {'Voice Call Event': ''}, 'General': {'GPS': {'DOP': '0.900000', 'DOP Type': 'HDOP', 'GPS Date Time (GMT)': '2021-04-05 22:36:04.000', 'Head': '42.000000', 'Height': '108.000000', 'Locked': 'Yes', 'Number of Satellites': '9', 'Speed': '0.000000'}, 'Serving Network': 'LTE (10 MHz)'}, 'IDX': '1954', 'LID': '1', 'LTE': {'L1': {'Misc': {'DL Band': '13', 'DL EARFCN': '5230'}, 'RF': {'PCI': '66', 'RS SINR': '10.260000', 'RSRP': '-82.220000'}}, 'Power': {'RSSI(RS_RSSI)': {'RS RSSI': '-51.100000'}}}, 'Lat': '31.8602867', 'Layer-3 Message': {'CDMA L3 Msg': '',
# ...
